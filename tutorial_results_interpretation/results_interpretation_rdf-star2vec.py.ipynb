# %%
import pandas as pd

# %%
import statistics

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# # Classification

# %% [markdown]
# ## Classification: Person, Object, and Place
# ### baseline (RDF2vec<sub>oa</sub>, v100)

# %%
# it contains classification results by using university data
filename3 = "../experiment/kgrc_baseline_Person_Object_Place_wang2vec/classification_kgrc_person_object_place_results.csv"
data3 = pd.read_csv(filename3, keep_default_na=False)

# %%
data3.head()
# Out:
#         task_name        gold_standard_file  coverage model_name  \
# 0  Classification  kgrc_person_object_place       1.0         NB
# 1  Classification  kgrc_person_object_place       1.0         NB
# 2  Classification  kgrc_person_object_place       1.0         NB
# 3  Classification  kgrc_person_object_place       1.0         NB
# 4  Classification  kgrc_person_object_place       1.0         NB
#
#   model_configuration  accuracy
# 0                      0.600000
# 1                      0.600000
# 2                      0.614815
# 3                      0.605556
# 4                      0.609259

# %%
# the best method able to manage university data
best_result_baseline = data3[data3.accuracy==max(data3.accuracy)]

# %%
best_result_baseline
# Out:
#          task_name        gold_standard_file  coverage model_name  \
# 55  Classification  kgrc_person_object_place       1.0        SVM
#
#    model_configuration  accuracy
# 55              C=10.0       0.8

# %% [markdown]
# ### baseline (RDF2vec<sub>classic</sub>, v100)

# %%
filename3 = "../experiment/kgrc_baseline_Person_Object_Place_word2vec/classification_kgrc_person_object_place_results.csv"
data3 = pd.read_csv(filename3, keep_default_na=False)

# %%
best_result_baseline = data3[data3.accuracy==max(data3.accuracy)]

# %%
best_result_baseline
# Out:
#          task_name        gold_standard_file  coverage model_name  \
# 41  Classification  kgrc_person_object_place       1.0        SVM
#
#    model_configuration  accuracy
# 41              C=10.0  0.744444

# %% [markdown]
# ### RDF-star2Vec, v100

# %%
# it contains classification results by using university data
filename4 = "../experiment/kgrc_rdfstar2vec_5_5_Person_Object_Place_wang2vec/classification_kgrc_person_object_place_results.csv"
data4 = pd.read_csv(filename4, keep_default_na=False)

# %%
data4.head()
# Out:
#         task_name        gold_standard_file  coverage model_name  \
# 0  Classification  kgrc_person_object_place       1.0         NB
# 1  Classification  kgrc_person_object_place       1.0         NB
# 2  Classification  kgrc_person_object_place       1.0         NB
# 3  Classification  kgrc_person_object_place       1.0         NB
# 4  Classification  kgrc_person_object_place       1.0         NB
#
#   model_configuration  accuracy
# 0                      0.692593
# 1                      0.698148
# 2                      0.698148
# 3                      0.692593
# 4                      0.694444

# %%
best_result_rdfstar2vec = data4[data4.accuracy==max(data4.accuracy)]

# %%
best_result_rdfstar2vec
# Out:
#          task_name        gold_standard_file  coverage model_name  \
# 89  Classification  kgrc_person_object_place       1.0        SVM
#
#    model_configuration  accuracy
# 89               C=1.0  0.822222

# %% [markdown]
# ### RDF-star2Vec<sub>classic</sub>

# %%
filename4 = "../experiment/kgrc_rdfstar2vec_5_5_Person_Object_Place_word2vec/classification_kgrc_person_object_place_results.csv"
data4 = pd.read_csv(filename4, keep_default_na=False)

# %%
best_result_rdfstar2vec = data4[data4.accuracy==max(data4.accuracy)]

# %%
best_result_rdfstar2vec
# Out:
#          task_name        gold_standard_file  coverage model_name  \
# 61  Classification  kgrc_person_object_place       1.0        SVM
#
#    model_configuration  accuracy
# 61               C=1.0  0.759259

# %% [markdown]
# ## Classification: Situation, Statement, Thought
# ### baseline (RDF2vec<sub>oa</sub>, v100)

# %%
# it contains classification results by using university data
file_qt900_baseline = "../experiment/kgrc_baseline_Situation_Statement_Thought_wang2vec/classification_kgrc_qt900_results.csv"
data_qt900_baseline = pd.read_csv(file_qt900_baseline, keep_default_na=False)

# %%
data_qt900_baseline.head()
# Out:
#         task_name gold_standard_file  coverage model_name model_configuration  \
# 0  Classification         kgrc_qt900       1.0         NB
# 1  Classification         kgrc_qt900       1.0         NB
# 2  Classification         kgrc_qt900       1.0         NB
# 3  Classification         kgrc_qt900       1.0         NB
# 4  Classification         kgrc_qt900       1.0         NB
#
#    accuracy
# 0  0.850000
# 1  0.848889
# 2  0.855556
# 3  0.850000
# 4  0.854444

# %%
# the best method able to manage university data
best_result_qt900_baseline = data_qt900_baseline[data_qt900_baseline.accuracy==max(data_qt900_baseline.accuracy)]

# %%
best_result_qt900_baseline
# Out:
#          task_name gold_standard_file  coverage model_name  \
# 56  Classification         kgrc_qt900       1.0        SVM
# 57  Classification         kgrc_qt900       1.0        SVM
#
#    model_configuration  accuracy
# 56               C=100  0.976667
# 57              C=1000  0.976667

# %% [markdown]
# ### baseline (RDF2vec<sub>classic</sub>, v100)

# %%
file_qt900_baseline = "../experiment/kgrc_baseline_Situation_Statement_Thought_word2vec/classification_kgrc_qt900_results.csv"
data_qt900_baseline = pd.read_csv(file_qt900_baseline, keep_default_na=False)

# %%
best_result_qt900_baseline = data_qt900_baseline[data_qt900_baseline.accuracy==max(data_qt900_baseline.accuracy)]

# %%
best_result_qt900_baseline
# Out:
#          task_name gold_standard_file  coverage model_name  \
# 49  Classification         kgrc_qt900       1.0        SVM
# 50  Classification         kgrc_qt900       1.0        SVM
#
#    model_configuration  accuracy
# 49               C=100  0.968889
# 50              C=1000  0.968889

# %% [markdown]
# ### RDF-star2Vec

# %%
file_qt900_rdfstar2vec = "../experiment/kgrc_rdfstar2vec_5_5_Situation_Statement_Thought_wang2vec/classification_kgrc_qt900_results.csv"
data_qt900_rdfstar2vec = pd.read_csv(file_qt900_rdfstar2vec, keep_default_na=False)

# %%
data_qt900_rdfstar2vec.head()
# Out:
#         task_name gold_standard_file  coverage model_name model_configuration  \
# 0  Classification         kgrc_qt900       1.0         NB
# 1  Classification         kgrc_qt900       1.0         NB
# 2  Classification         kgrc_qt900       1.0         NB
# 3  Classification         kgrc_qt900       1.0         NB
# 4  Classification         kgrc_qt900       1.0         NB
#
#    accuracy
# 0  0.856667
# 1  0.848889
# 2  0.857778
# 3  0.855556
# 4  0.854444

# %%
best_result_qt900_rdfstar2vec = data_qt900_rdfstar2vec[data_qt900_rdfstar2vec.accuracy==max(data_qt900_rdfstar2vec.accuracy)]

# %%
best_result_qt900_rdfstar2vec
# Out:
#          task_name gold_standard_file  coverage model_name  \
# 90  Classification         kgrc_qt900       1.0        SVM
# 91  Classification         kgrc_qt900       1.0        SVM
# 92  Classification         kgrc_qt900       1.0        SVM
#
#    model_configuration  accuracy
# 90              C=10.0  0.974444
# 91               C=100  0.974444
# 92              C=1000  0.974444

# %% [markdown]
# ### RDF-star2Vec<sub>classic</sub>, v100

# %%
file_qt900_rdfstar2vec = "../experiment/kgrc_rdfstar2vec_5_5_Situation_Statement_Thought_word2vec/classification_kgrc_qt900_results.csv"
data_qt900_rdfstar2vec = pd.read_csv(file_qt900_rdfstar2vec, keep_default_na=False)

# %%
best_result_qt900_rdfstar2vec = data_qt900_rdfstar2vec[data_qt900_rdfstar2vec.accuracy==max(data_qt900_rdfstar2vec.accuracy)]

# %%
best_result_qt900_rdfstar2vec
# Out:
#          task_name gold_standard_file  coverage model_name  \
# 62  Classification         kgrc_qt900       1.0        SVM
# 63  Classification         kgrc_qt900       1.0        SVM
# 64  Classification         kgrc_qt900       1.0        SVM
#
#    model_configuration  accuracy
# 62              C=10.0  0.971111
# 63               C=100  0.971111
# 64              C=1000  0.971111

# %% [markdown]
# # Clustering
# ## Clustering: Person, Object, and Place
# ### baseline (RDF2vec<sub>oa</sub>, v100)

# %%
# it contains classification results by using university data
filename = "../experiment/kgrc_baseline/clustering_kgrc_person_object_place_results.csv"

# %%
data = pd.read_csv(filename, keep_default_na=False)

# %%
data.head()
# Out:
#     task_name        gold_standard_file  coverage  \
# 0  Clustering  kgrc_person_object_place       1.0
# 1  Clustering  kgrc_person_object_place       1.0
# 2  Clustering  kgrc_person_object_place       1.0
# 3  Clustering  kgrc_person_object_place       1.0
#
#                      model_name             model_configuration  num_clusters  \
# 0                        DBSCAN                   metric=cosine            63
# 1                        KMeans  metric=enclidean, n_clusters=3             3
# 2      Agglomerative clustering     metric=cosine, n_clusters=3             3
# 3  Ward hierarchical clustering     metric=cosine, n_clusters=3             3
#
#    adjusted_rand_index  adjusted_mutual_info_score  homogeneity_score  \
# 0             0.009367                    0.029786           0.140961
# 1             0.388012                    0.369237           0.364213
# 2             0.063939                    0.063192           0.065374
# ...

# %% [markdown]
# ### baseline (RDF2vec<sub>classic</sub>, v100)

# %%
# it contains classification results by using university data
filename = "../experiment/kgrc_baseline_word2vec/clustering_kgrc_person_object_place_results.csv"

# %%
data = pd.read_csv(filename, keep_default_na=False)

# %%
data.head()
# Out:
#     task_name        gold_standard_file  coverage  \
# 0  Clustering  kgrc_person_object_place       1.0
# 1  Clustering  kgrc_person_object_place       1.0
# 2  Clustering  kgrc_person_object_place       1.0
# 3  Clustering  kgrc_person_object_place       1.0
#
#                      model_name             model_configuration  num_clusters  \
# 0                        DBSCAN                   metric=cosine            34
# 1                        KMeans  metric=enclidean, n_clusters=3             3
# 2      Agglomerative clustering     metric=cosine, n_clusters=3             3
# 3  Ward hierarchical clustering     metric=cosine, n_clusters=3             3
#
#    adjusted_rand_index  adjusted_mutual_info_score  homogeneity_score  \
# 0             0.001481                    0.002975           0.063277
# 1             0.188507                    0.178834           0.169228
# 2            -0.002196                   -0.001946           0.001471
# ...

# %% [markdown]
# ### RDF-star2Vec, v100

# %%
# it contains classification results by using university data
filename2 = "../experiment/kgrc_rdfstar2vec/clustering_kgrc_person_object_place_results.csv"
data2 = pd.read_csv(filename2, keep_default_na=False)

# %%
data2.head()
# Out:
#     task_name        gold_standard_file  coverage  \
# 0  Clustering  kgrc_person_object_place       1.0
# 1  Clustering  kgrc_person_object_place       1.0
# 2  Clustering  kgrc_person_object_place       1.0
# 3  Clustering  kgrc_person_object_place       1.0
#
#                      model_name             model_configuration  num_clusters  \
# 0                        DBSCAN                   metric=cosine           254
# 1                        KMeans  metric=enclidean, n_clusters=3             3
# 2      Agglomerative clustering     metric=cosine, n_clusters=3             3
# 3  Ward hierarchical clustering     metric=cosine, n_clusters=3             3
#
#    adjusted_rand_index  adjusted_mutual_info_score  homogeneity_score  \
# 0             0.034208                    0.063649           0.597618
# 1             0.653051                    0.583721           0.584231
# 2             0.065474                    0.064144           0.064799
# ...

# %% [markdown]
# ### RDF-star2Vec<sub>classic</sub>, v100

# %%
# it contains classification results by using university data
filename2 = "../experiment/kgrc_rdfstar2vec_word2vec/clustering_kgrc_person_object_place_results.csv"
data2 = pd.read_csv(filename2, keep_default_na=False)

# %%
data2.head()
# Out:
#     task_name        gold_standard_file  coverage  \
# 0  Clustering  kgrc_person_object_place       1.0
# 1  Clustering  kgrc_person_object_place       1.0
# 2  Clustering  kgrc_person_object_place       1.0
# 3  Clustering  kgrc_person_object_place       1.0
#
#                      model_name             model_configuration  num_clusters  \
# 0                        DBSCAN                   metric=cosine           165
# 1                        KMeans  metric=enclidean, n_clusters=3             3
# 2      Agglomerative clustering     metric=cosine, n_clusters=3             3
# 3  Ward hierarchical clustering     metric=cosine, n_clusters=3             3
#
#    adjusted_rand_index  adjusted_mutual_info_score  homogeneity_score  \
# 0             0.002414                    0.028129           0.348719
# 1             0.102966                    0.091715           0.091396
# 2             0.074483                    0.065749           0.066465
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# ## Clustering: Situation, Statement, and Thought
# ### baseline (RDF2vec<sub>oa</sub>, v100)

# %%
file_qt900_baseline = "../experiment/kgrc_baseline/clustering_kgrc_qt900_results.csv"

# %%
data_qt900_baseline = pd.read_csv(file_qt900_baseline, keep_default_na=False)

# %%
data_qt900_baseline.head()
# Out:
#     task_name gold_standard_file  coverage                    model_name  \
# 0  Clustering         kgrc_qt900       1.0                        DBSCAN
# 1  Clustering         kgrc_qt900       1.0                        KMeans
# 2  Clustering         kgrc_qt900       1.0      Agglomerative clustering
# 3  Clustering         kgrc_qt900       1.0  Ward hierarchical clustering
#
#               model_configuration  num_clusters  adjusted_rand_index  \
# 0                   metric=cosine            57             0.051120
# 1  metric=enclidean, n_clusters=3             3             0.314086
# 2     metric=cosine, n_clusters=3             3             0.177368
# 3     metric=cosine, n_clusters=3             3             0.366361
#
#    adjusted_mutual_info_score  homogeneity_score  completeness_score  \
# 0                    0.110046           0.205686            0.118748
# 1                    0.323817           0.322547            0.327898
# ...

# %% [markdown]
# ### baseline (RDF2vec<sub>classic</sub>, v100)

# %%
file_qt900_baseline = "../experiment/kgrc_baseline_word2vec/clustering_kgrc_qt900_results.csv"

# %%
data_qt900_baseline = pd.read_csv(file_qt900_baseline, keep_default_na=False)

# %%
data_qt900_baseline.head()
# Out:
#     task_name gold_standard_file  coverage                    model_name  \
# 0  Clustering         kgrc_qt900       1.0                        DBSCAN
# 1  Clustering         kgrc_qt900       1.0                        KMeans
# 2  Clustering         kgrc_qt900       1.0      Agglomerative clustering
# 3  Clustering         kgrc_qt900       1.0  Ward hierarchical clustering
#
#               model_configuration  num_clusters  adjusted_rand_index  \
# 0                   metric=cosine            23             0.013422
# 1  metric=enclidean, n_clusters=3             3             0.440896
# 2     metric=cosine, n_clusters=3             3             0.358706
# 3     metric=cosine, n_clusters=3             3             0.335883
#
#    adjusted_mutual_info_score  homogeneity_score  completeness_score  \
# 0                    0.058516           0.069357            0.118824
# 1                    0.453186           0.429561            0.482200
# ...

# %% [markdown]
# ### RDF-star2Vec, v100

# %%
file_qt900_rdfstar2vec = "../experiment/kgrc_rdfstar2vec/clustering_kgrc_qt900_results.csv"

# %%
data_qt900_rdfstar2vec = pd.read_csv(file_qt900_rdfstar2vec, keep_default_na=False)

# %%
data_qt900_rdfstar2vec.head()
# Out:
#     task_name gold_standard_file  coverage                    model_name  \
# 0  Clustering         kgrc_qt900       1.0                        DBSCAN
# 1  Clustering         kgrc_qt900       1.0                        KMeans
# 2  Clustering         kgrc_qt900       1.0      Agglomerative clustering
# 3  Clustering         kgrc_qt900       1.0  Ward hierarchical clustering
#
#               model_configuration  num_clusters  adjusted_rand_index  \
# 0                   metric=cosine            68             0.071913
# 1  metric=enclidean, n_clusters=3             3             0.066160
# 2     metric=cosine, n_clusters=3             3             0.064886
# 3     metric=cosine, n_clusters=3             3             0.065901
#
#    adjusted_mutual_info_score  homogeneity_score  completeness_score  \
# 0                    0.109320           0.242777            0.108980
# 1                    0.069586           0.066342            0.077824
# ...

# %% [markdown]
# ### RDF-star2Vec<sub>classic</sub>, v100

# %%
file_qt900_rdfstar2vec = "../experiment/kgrc_rdfstar2vec_word2vec/clustering_kgrc_qt900_results.csv"

# %%
data_qt900_rdfstar2vec = pd.read_csv(file_qt900_rdfstar2vec, keep_default_na=False)

# %%
data_qt900_rdfstar2vec.head()
# Out:
#     task_name gold_standard_file  coverage                    model_name  \
# 0  Clustering         kgrc_qt900       1.0                        DBSCAN
# 1  Clustering         kgrc_qt900       1.0                        KMeans
# 2  Clustering         kgrc_qt900       1.0      Agglomerative clustering
# 3  Clustering         kgrc_qt900       1.0  Ward hierarchical clustering
#
#               model_configuration  num_clusters  adjusted_rand_index  \
# 0                   metric=cosine            35             0.076057
# 1  metric=enclidean, n_clusters=3             3             0.066160
# 2     metric=cosine, n_clusters=3             3             0.066160
# 3     metric=cosine, n_clusters=3             3             0.066160
#
#    adjusted_mutual_info_score  homogeneity_score  completeness_score  \
# 0                    0.107865           0.190902            0.099204
# 1                    0.069586           0.066342            0.077824
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# # Entity Relatedness

# %% [markdown]
# ## baseline (RDF2vec<sub>oa</sub>, v100)

# %%
# it contains classification results by using university data
filename_er_baseline = "../experiment/kgrc_baseline/entityRelatedness_kgrc_entity_relatedness_results.csv"
data_er_baseline = pd.read_csv(filename_er_baseline, keep_default_na=False)

# %%
data_er_baseline
# Out:
#             task_name       gold_standard_file  coverage  \
# 0   EntityRelatedness  kgrc_entity_relatedness       1.0
# 1   EntityRelatedness  kgrc_entity_relatedness       1.0
# 2   EntityRelatedness  kgrc_entity_relatedness       1.0
# 3   EntityRelatedness  kgrc_entity_relatedness       1.0
# 4   EntityRelatedness  kgrc_entity_relatedness       1.0
# 5   EntityRelatedness  kgrc_entity_relatedness       1.0
# 6   EntityRelatedness  kgrc_entity_relatedness       1.0
# 7   EntityRelatedness  kgrc_entity_relatedness       1.0
# 8   EntityRelatedness  kgrc_entity_relatedness       1.0
# 9   EntityRelatedness  kgrc_entity_relatedness       1.0
# 10  EntityRelatedness  kgrc_entity_relatedness       1.0
# 11  EntityRelatedness  kgrc_entity_relatedness       1.0
# 12  EntityRelatedness  kgrc_entity_relatedness       1.0
# 13  EntityRelatedness  kgrc_entity_relatedness       1.0
# 14  EntityRelatedness  kgrc_entity_relatedness       1.0
# ...

# %%
max_er_result_baseline = data_er_baseline[data_er_baseline.kendalltau_correlation == max(data_er_baseline.kendalltau_correlation)]

# %%
max_er_result_baseline
# Out:
#             task_name       gold_standard_file  coverage  entity_name  \
# 20  EntityRelatedness  kgrc_entity_relatedness       1.0  df:Mortimer
#
#     kendalltau_correlation  kendalltau_pvalue
# 20                0.466667            0.07255

# %% [markdown]
# ## baseline (RDF2vec<sub>classic</sub>, v100)

# %%
filename_er_baseline = "../experiment/kgrc_baseline_word2vec/entityRelatedness_kgrc_entity_relatedness_results.csv"
data_er_baseline = pd.read_csv(filename_er_baseline, keep_default_na=False)

# %%
max_er_result_baseline = data_er_baseline[data_er_baseline.kendalltau_correlation == max(data_er_baseline.kendalltau_correlation)]

# %%
max_er_result_baseline
# Out:
#             task_name       gold_standard_file  coverage    entity_name  \
# 12  EntityRelatedness  kgrc_entity_relatedness       1.0  ci:Sutherland
# 14  EntityRelatedness  kgrc_entity_relatedness       1.0       cm:Nancy
#
#     kendalltau_correlation  kendalltau_pvalue
# 12                0.422222           0.108313
# 14                0.422222           0.108313

# %% [markdown]
# ## RDF-star2Vec, v100

# %%
# it contains classification results by using university data
filename_er_rdfstar2vec = "../experiment/kgrc_rdfstar2vec/entityRelatedness_kgrc_entity_relatedness_results.csv"
data_er_rdfstar2vec = pd.read_csv(filename_er_rdfstar2vec, keep_default_na=False)

# %%
data_er_rdfstar2vec
# Out:
#             task_name       gold_standard_file  coverage  \
# 0   EntityRelatedness  kgrc_entity_relatedness       1.0
# 1   EntityRelatedness  kgrc_entity_relatedness       1.0
# 2   EntityRelatedness  kgrc_entity_relatedness       1.0
# 3   EntityRelatedness  kgrc_entity_relatedness       1.0
# 4   EntityRelatedness  kgrc_entity_relatedness       1.0
# 5   EntityRelatedness  kgrc_entity_relatedness       1.0
# 6   EntityRelatedness  kgrc_entity_relatedness       1.0
# 7   EntityRelatedness  kgrc_entity_relatedness       1.0
# 8   EntityRelatedness  kgrc_entity_relatedness       1.0
# 9   EntityRelatedness  kgrc_entity_relatedness       1.0
# 10  EntityRelatedness  kgrc_entity_relatedness       1.0
# 11  EntityRelatedness  kgrc_entity_relatedness       1.0
# 12  EntityRelatedness  kgrc_entity_relatedness       1.0
# 13  EntityRelatedness  kgrc_entity_relatedness       1.0
# 14  EntityRelatedness  kgrc_entity_relatedness       1.0
# ...

# %%
max_er_result_rdfstar2vec = data_er_rdfstar2vec[data_er_rdfstar2vec.kendalltau_correlation == max(data_er_rdfstar2vec.kendalltau_correlation)]

# %%
max_er_result_rdfstar2vec
# Out:
#            task_name       gold_standard_file  coverage     entity_name  \
# 8  EntityRelatedness  kgrc_entity_relatedness       1.0  ag:Jack_Croker
#
#    kendalltau_correlation  kendalltau_pvalue
# 8                0.555556           0.028609

# %% [markdown]
# ## RDF-star2Vec<sub>classic</sub>, v100

# %%
filename_er_rdfstar2vec = "../experiment/kgrc_rdfstar2vec_word2vec/entityRelatedness_kgrc_entity_relatedness_results.csv"
data_er_rdfstar2vec = pd.read_csv(filename_er_rdfstar2vec, keep_default_na=False)

# %%
max_er_result_rdfstar2vec = data_er_rdfstar2vec[data_er_rdfstar2vec.kendalltau_correlation == max(data_er_rdfstar2vec.kendalltau_correlation)]

# %%
max_er_result_rdfstar2vec
# Out:
#             task_name       gold_standard_file  coverage entity_name  \
# 14  EntityRelatedness  kgrc_entity_relatedness       1.0    cm:Nancy
#
#     kendalltau_correlation  kendalltau_pvalue
# 14                     0.6           0.016666

# %% [markdown]
# # Document Similarity (Quoted Triple Similarity)
# ## baseline (RDF2vec<sub>oa</sub>, v100)

# %%
filename_ds_baseline = "../experiment/kgrc_baseline/documentSimilarity_LP50_results.csv"
data_ds_baseline = pd.read_csv(filename_ds_baseline, keep_default_na=False)

# %%
data_ds_baseline
# Out:
#             task_name gold_standard_file  coverage             conf  \
# 0  DocumentSimilarity               LP50       1.0     with_weights
# 1  DocumentSimilarity               LP50       1.0  without_weights
#
#    pearson_score  spearman_score  harmonic_mean
# 0        0.02995        0.003189       0.005764
# 1        0.02995        0.003189       0.005764

# %% [markdown]
# ## baseline (RDF2vec<sub>classic</sub>, v100)

# %%
filename_ds_baseline = "../experiment/kgrc_baseline_word2vec/documentSimilarity_LP50_results.csv"
data_ds_baseline = pd.read_csv(filename_ds_baseline, keep_default_na=False)

# %%
data_ds_baseline
# Out:
#             task_name gold_standard_file  coverage             conf  \
# 0  DocumentSimilarity               LP50       1.0     with_weights
# 1  DocumentSimilarity               LP50       1.0  without_weights
#
#    pearson_score  spearman_score  harmonic_mean
# 0       0.032529        0.010109       0.015424
# 1       0.032529        0.010109       0.015424

# %% [markdown]
# ## RDF-star2Vec, v100

# %%
filename_ds_rdfstar2vec = "../experiment/kgrc_rdfstar2vec/documentSimilarity_LP50_results.csv"
data_ds_rdfstar2vec = pd.read_csv(filename_ds_rdfstar2vec, keep_default_na=False)

# %%
data_ds_rdfstar2vec
# Out:
#             task_name gold_standard_file  coverage             conf  \
# 0  DocumentSimilarity               LP50       1.0     with_weights
# 1  DocumentSimilarity               LP50       1.0  without_weights
#
#    pearson_score  spearman_score  harmonic_mean
# 0       0.100002        0.039053        0.05617
# 1       0.100002        0.039053        0.05617

# %% [markdown]
# ## RDF-star2Vec<sub>classic</sub>, v100

# %%
filename_ds_rdfstar2vec = "../experiment/kgrc_rdfstar2vec_word2vec/documentSimilarity_LP50_results.csv"
data_ds_rdfstar2vec = pd.read_csv(filename_ds_rdfstar2vec, keep_default_na=False)

# %%
data_ds_rdfstar2vec
# Out:
#             task_name gold_standard_file  coverage             conf  \
# 0  DocumentSimilarity               LP50       1.0     with_weights
# 1  DocumentSimilarity               LP50       1.0  without_weights
#
#    pearson_score  spearman_score  harmonic_mean
# 0       0.116514        0.056846       0.076412
# 1       0.116514        0.056846       0.076412

# %% [markdown]
# <hr>
